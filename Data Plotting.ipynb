# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import os
currPth = os.getcwd()
print(currPth)
import sys
sys.path.append("//Users/jamesklovell/Documents/GitHub/fastai/") # go to parent dir
# Out:
# /home/ubuntu/fastai/courses/data/EnergyPriceDLModel

# %%
PATH = "//home/ubuntu/fastai/courses/data/EnergyPriceDLModel/"
#PATH = "C:\\Users\\jamesklovell\\Documents\\GitHub\\EnergyPriceDLModel\\"

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv(f'{PATH}Train2000Jan13.csv', parse_dates=['DateTime'])
df.head()
# Out:
#              DateTime      Demand  Price
# 0 2000-01-01 02:30:00  3615.71333  18.55
# 1 2000-01-01 05:30:00  3280.89333  17.50
# 2 2000-01-01 08:30:00  3801.56833  17.46
# 3 2000-01-01 11:30:00  4185.38833  18.56
# 4 2000-01-01 14:30:00  4087.32500  17.50

# %%
plt.plot(df['DateTime'], df['Price'], marker='', color='red', linewidth=2, linestyle='solid')
#plt.gcf().autofmt_xdate()
#dateFmt = mdates.DateFormatter('%H:%M')
#plt.gca().xaxis.set_major_formatter(dateFmt)
#plt.show()

# %%
data_2004_2007 = pd.read_csv(f'{PATH}Train2000JanJun.csv', parse_dates=['DateTime'])
dataPlot = plt.plot(data_2004_2007['Price'], 'b-')

# %%
data_2008_2011 = pd.read_csv(f'{PATH}Train2000JanJun.csv', parse_dates=['DateTime'])
dataPlot = plt.plot(data_2008_2011['Price'], 'b.')

# %%
data_2012_2014 = pd.read_csv(f'{PATH}Train2012_2014nw_100.csv', parse_dates=['DateTime'])
dataPlot = plt.plot(data_2012_2014['DateTime'],data_2012_2014['Price'], 'b.')

# %%
data_2015_2018 = pd.read_csv(f'{PATH}Train2015_2018nw_100.csv', parse_dates=['DateTime'])
dataPlot = plt.plot(data_2015_2018['DateTime'],data_2015_2018['Price'], 'b.')

# %%
data_Test = pd.read_csv(f'{PATH}Testnw.csv', parse_dates=['DateTime'])
dataPlot = plt.plot(data_Test['DateTime'],data_Test['Demand'], 'b.')
