# %% [markdown]
# Initialise, set the path and import librarys

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import os
currPth = os.getcwd()
print(currPth)
import sys
sys.path.append("//home/ubuntu/fastai/") # go to parent dir
# Out:
# /home/ubuntu/fastai/courses/data/EnergyPriceDLModel

# %% [markdown]
#     (For some reason I have to tell FastAI where the parent dir is)

# %% [markdown]
# Import everything needed

# %%
from fastai.imports import *
from fastai.torch_imports import *
from fastai.dataset import *
from fastai.dataset import *
from fastai.plots import *

from fastai.structured import *
from fastai.column_data import *
np.set_printoptions(threshold=50, edgeitems=20)

from sklearn_pandas import DataFrameMapper
from sklearn.preprocessing import LabelEncoder, Imputer, StandardScaler

from IPython.display import HTML

# %%
PATH="//home/ubuntu/fastai/courses/data/EnergyPriceDLModel/"

# %% [markdown]
# Set the Training & Testing data sets, import them from csv, parse the Date Column, have a look at it

# %%
data_Train = pd.read_csv(f'{PATH}Train_144MAVpc1K.csv', parse_dates=['Date'])
data_Train
# Out:
#          Index       Date   Time      TimeOfDay      Demand  DemandMAV  \
# 0          144 2000-04-01   0:00       Midnight  4365.84000   4084.432
# 1          145 2000-04-01   0:30       Midnight  4074.58667   4085.113
# 2          146 2000-04-01   1:00       Midnight  3878.08333   4086.287
# 3          147 2000-04-01   1:30       Midnight  3699.40667   4086.442
# 4          148 2000-04-01   2:00       Midnight  3617.21333   4085.644
# 5          149 2000-04-01   2:30       Midnight  3559.15833   4085.031
# 6          150 2000-04-01   3:00  Early Morning  3515.90833   4084.639
# 7          151 2000-04-01   3:30  Early Morning  3496.85667   4084.630
# 8          152 2000-04-01   4:00  Early Morning  3502.48500   4085.006
# 9          153 2000-04-01   4:30  Early Morning  3551.45667   4085.911
# 10         154 2000-04-01   5:00  Early Morning  3583.71667   4087.439
# 11         155 2000-04-01   5:30  Early Morning  3634.32500   4089.379
# 12         156 2000-04-01   6:00        Morning  3765.45000   4091.833
# 13         157 2000-04-01   6:30        Morning  4049.29500   4095.213
# 14         158 2000-04-01   7:00        Morning  4361.11167   4100.230
# 15         159 2000-04-01   7:30        Morning  4653.57000   4106.927
# 16         160 2000-04-01   8:00        Morning  4877.45833   4114.843
# 17         161 2000-04-01   8:30        Morning  5139.79333   4123.591
# 18         162 2000-04-01   9:00         Midday  5319.14667   4132.884
# 19         163 2000-04-01   9:30         Midday  5351.77000   4142.621
# 20         164 2000-04-01  10:00         Midday  5340.09667   4152.143
# 21         165 2000-04-01  10:30         Midday  5348.92000   4160.992
# 22         166 2000-04-01  11:00         Midday  5345.12667   4169.544
# 23         167 2000-04-01  11:30         Midday  5330.91833   4177.668
# 24         168 2000-04-01  12:00      Afternoon  5345.08167   4185.623
# 25         169 2000-04-01  12:30      Afternoon  5316.72333   4193.702
# 26         170 2000-04-01  13:00      Afternoon  5305.75000   4201.567
# 27         171 2000-04-01  13:30      Afternoon  5309.52000   4209.487
# 28         172 2000-04-01  14:00      Afternoon  5317.73000   4217.748
# 29         173 2000-04-01  14:30      Afternoon  5352.03500   4226.156
# ...        ...        ...    ...            ...         ...        ...
# 315418  315562 2017-12-31   9:00         Midday  6219.05000   6598.896
# 315419  315563 2017-12-31   9:30         Midday  6360.48000   6598.172
# 315420  315564 2017-12-31  10:00         Midday  6461.40000   6597.728
# 315421  315565 2017-12-31  10:30         Midday  6579.80000   6597.882
# 18    162 2017-05-12  9:00         Midday  6689.18   6351.857      0
# 19    163 2017-05-12  9:30         Midday  6564.60   6355.766      0
#
#     PriceMAV  MaxTemp  MinTemp  Rainfall
# 0          0     30.5     17.0      23.6
# 1          0     30.5     17.0      23.6
# 2          0     30.5     17.0      23.6
# 3          0     30.5     17.0      23.6
# 4          0     30.5     17.0      23.6
# 5          0     30.5     17.0      23.6
# 6          0     30.5     17.0      23.6
# 7          0     30.5     17.0      23.6
# 8          0     30.5     17.0      23.6
# 9          0     30.5     17.0      23.6
# 10         0     30.5     17.0      23.6
# 11         0     30.5     17.0      23.6
# 12         0     30.5     17.0      23.6
# 13         0     30.5     17.0      23.6
# 14         0     30.5     17.0      23.6
# 15         0     30.5     17.0      23.6
# 16         0     30.5     17.0      23.6
# 17         0     30.5     17.0      23.6
# 18         0     30.5     17.0      23.6
# 19         0     30.5     17.0      23.6

# %% [markdown]
# Check lengths of data set

# %%
len(data_Train)
# Out:
# 315448

# %%
len(data_Test)
# Out:
# 9071

# %% [markdown]
# Add Extra Date information

# %%
add_datepart(data_Train, "Date", drop=False)

# %%
add_datepart(data_Test, "Date", drop=False)

# %% [markdown]
# Adjust Columns, discard unnecessary data

# %%
data_Train.columns
# Out:
# Index(['Index', 'Date', 'Time', 'TimeOfDay', 'Demand', 'DemandMAV', 'Price',
#        'PriceMAV', 'MaxTemp', 'MinTemp', 'Rainfall', 'Year', 'Month', 'Week',
#        'Day', 'Dayofweek', 'Dayofyear', 'Is_month_end', 'Is_month_start',
#        'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start',
#        'Elapsed'],
#       dtype='object')

# %%
data_Test.columns
# Out:
# Index(['Index', 'Date', 'Time', 'TimeOfDay', 'Demand', 'DemandMAV', 'Price',
#        'PriceMAV', 'MaxTemp', 'MinTemp', 'Rainfall', 'Year', 'Month', 'Week',
#        'Day', 'Dayofweek', 'Dayofyear', 'Is_month_end', 'Is_month_start',
#        'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start',
#        'Elapsed'],
#       dtype='object')

# %%
columns = ['Demand','Price','Is_month_end', 'Is_month_start', 'Is_quarter_end',
       'Is_quarter_start', 'Is_year_end', 'Is_year_start', 'Elapsed']

# %%
data_Train.drop(columns,1,inplace=True)

# %%
columns = ['Demand','Price','PriceMAV','Is_month_end', 'Is_month_start', 'Is_quarter_end',
       'Is_quarter_start', 'Is_year_end', 'Is_year_start', 'Elapsed']

# %%
data_Test.drop(columns,1,inplace=True)

# %%
data_Train.columns
# Out:
# Index(['Index', 'Date', 'Time', 'TimeOfDay', 'DemandMAV', 'PriceMAV',
#        'MaxTemp', 'MinTemp', 'Rainfall', 'Year', 'Month', 'Week', 'Day',
#        'Dayofweek', 'Dayofyear'],
#       dtype='object')

# %%
data_Test.columns
# Out:
# Index(['Index', 'Date', 'Time', 'TimeOfDay', 'DemandMAV', 'MaxTemp', 'MinTemp',
#        'Rainfall', 'Year', 'Month', 'Week', 'Day', 'Dayofweek', 'Dayofyear'],
#       dtype='object')

# %% [markdown]
# Backup to feather

# %%
data_Train.reset_index(inplace=True)
data_Test.reset_index(inplace=True)

# %%
data_Train.to_feather(f'{PATH}df')
data_Test.to_feather(f'{PATH}df_test')

# %% [markdown]
# Load the data from Feather

# %%
data_Train = pd.read_feather(f'{PATH}df')

# %%
data_Test= pd.read_feather(f'{PATH}df_test')

# %% [markdown]
# Convert DateTime to datetime for both datasets

# %%
data_Train["Date"] = pd.to_datetime(data_Train.Date)

# %%
data_Test["Date"] = pd.to_datetime(data_Test.Date)

# %% [markdown]
# Check data

# %%
data_Train.head().T.head(12)
# Out:
#                              0                    1                    2  \
# index                        0                    1                    2
# Index                      144                  145                  146
# Date       2000-04-01 00:00:00  2000-04-01 00:00:00  2000-04-01 00:00:00
# Time                      0:00                 0:30                 1:00
# TimeOfDay             Midnight             Midnight             Midnight
# DemandMAV              4084.43              4085.11              4086.29
# PriceMAV               21.7386              21.1373              20.9932
# MaxTemp                     28                   28                   28
# MinTemp                     19                   19                   19
# Rainfall                  0.01                 0.01                 0.01
# Year                      2000                 2000                 2000
# Month                        4                    4                    4
#
#                              3                    4
# index                        3                    4
# Index                      147                  148
# Date       2000-04-01 00:00:00  2000-04-01 00:00:00
# Time                      1:30                 2:00
# TimeOfDay             Midnight             Midnight
# DemandMAV              4086.44              4085.64
# PriceMAV               20.8774              20.7544
# MaxTemp                     28                   28
# MinTemp                     19                   19
# Rainfall                  0.01                 0.01
# Year                      2000                 2000
# Month                        4                    4

# %% [markdown]
# Set Category and Continuous Variables

# %%
cat_vars = ['Date', 'Time','TimeOfDay','Year', 'Month', 'Week', 'Day', 'Dayofweek', 'Dayofyear']
contin_vars = ['DemandMAV']
n = len(data_Train); n
# Out:
# 315448

# %%
dep = 'PriceMAV'
data_Train = data_Train[cat_vars+contin_vars+[dep, 'Index']].copy()

# %%
data_Test[dep] = 0
data_Test = data_Test[cat_vars+contin_vars+[dep, 'Index']].copy()

# %%
for v in cat_vars: data_Train[v] = data_Train[v].astype('category').cat.as_ordered()

# %%
data_Test.columns
# Out:
# Index(['Date', 'Time', 'TimeOfDay', 'Year', 'Month', 'Week', 'Day',
#        'Dayofweek', 'Dayofyear', 'DemandMAV', 'PriceMAV', 'Index'],
#       dtype='object')

# %%
data_Train.columns
# Out:
# Index(['Date', 'Time', 'TimeOfDay', 'Year', 'Month', 'Week', 'Day',
#        'Dayofweek', 'Dayofyear', 'DemandMAV', 'PriceMAV', 'Index'],
#       dtype='object')

# %%
apply_cats(data_Test, data_Train)

# %% [markdown]
# Set Continuous Variables to Float32

# %%
for v in contin_vars:
    data_Train[v] = data_Train[v].astype('float32')
    data_Test[v] = data_Test[v].astype('float32')

# %% [markdown]
# Set DateTime as index for both

# %%
data_Train = data_Train.set_index("Index")

# %%
data_Test = data_Test.set_index("Index")

# %% [markdown]
# Split off response variable (Price) and convert dataframe to entirely numeric data

# %%
df, y, nas, mapper = proc_df(data_Train, 'PriceMAV', do_scale=True)
yl = np.log(y)

# %%
df_test, _, nas, mapper = proc_df(data_Test, 'PriceMAV', do_scale=True, mapper=mapper, na_dict=nas)

# %% [markdown]
# Set validation set to last 25% of Training set

# %%
samp_size = len(df)

# %%
#train_ratio = 0.65
train_ratio = 0.75
# train_ratio = 0.9
train_size = int(samp_size * train_ratio); train_size
val_idx = list(range(train_size, len(df)))

# %% [markdown]
# Define Root-mean-squared percent error to use as metric

# %%
def inv_y(a): return np.exp(a)

def exp_rmspe(y_pred, targ):
    targ = inv_y(targ)
    pct_var = (targ - inv_y(y_pred))/targ
    return math.sqrt((pct_var**2).mean())

max_log_y = np.max(yl)
y_range = (0, max_log_y*1.2)

# %% [markdown]
# Create ModelData from DataFrame

# %%
md = ColumnarModelData.from_data_frame(PATH, val_idx, df, yl.astype(np.float32), cat_flds=cat_vars, bs=64,
                                      test_df=df_test)

# %% [markdown]
# Use the cardinal for each Categorical variable for embeddings

# %%
cat_sz = [(c, len(data_Train[c].cat.categories)+1) for c in cat_vars]

# %%
cat_sz
# Out:
# [('Date', 6573),
#  ('Time', 49),
#  ('TimeOfDay', 9),
#  ('Year', 19),
#  ('Month', 13),
#  ('Week', 54),
#  ('Day', 32),
#  ('Dayofweek', 8),
#  ('Dayofyear', 367)]

# %%
emb_szs = [(c, min(50, (c+1)//2)) for _,c in cat_sz]

# %%
emb_szs
# Out:
# [(6573, 50),
#  (49, 25),
#  (9, 5),
#  (19, 10),
#  (13, 7),
#  (54, 27),
#  (32, 16),
#  (8, 4),
#  (367, 50)]

# %% [markdown]
# Find a Learning Rate

# %%
m = md.get_learner(emb_szs, len(df.columns)-len(cat_vars),0.04, 1, [1000,500], [0.001,0.01],y_range=y_range)
lr = 0.001

# %%
m
# Out:
# MixedInputModel(
#   (embs): ModuleList(
#     (0): Embedding(6573, 50)
#     (1): Embedding(49, 25)
#     (2): Embedding(9, 5)
#     (3): Embedding(19, 10)
#     (4): Embedding(13, 7)
#     (5): Embedding(54, 27)
#     (6): Embedding(32, 16)
#     (7): Embedding(8, 4)
#     (8): Embedding(367, 50)
#   )
#   (lins): ModuleList(
#     (0): Linear(in_features=195, out_features=1000, bias=True)
#     (1): Linear(in_features=1000, out_features=500, bias=True)
#   )
#   (bns): ModuleList(
#     (0): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True)
#     (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (outp): Linear(in_features=500, out_features=1, bias=True)
#   (emb_drop): Dropout(p=0.04)
#   (drops): ModuleList(
#     (0): Dropout(p=0.001)
#     (1): Dropout(p=0.01)
#   )
#   (bn): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True)
# )

# %%
m.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  20%|█▉        | 736/3697 [00:05<00:21, 138.60it/s, loss=0.0651]
#  20%|██        | 751/3697 [00:05<00:21, 136.24it/s, loss=0.0611]
# Exception in thread Thread-26:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/fastai/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/fastai/lib/python3.6/site-packages/tqdm/_monitor.py", line 62, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/ubuntu/anaconda3/envs/fastai/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#  56%|█████▌    | 2056/3697 [00:14<00:11, 138.02it/s, loss=0.0647]

# %%
m.sched.plot(100)

# %% [markdown]
# Do some initial learning

# %%
m = md.get_learner(emb_szs, len(df.columns)-len(cat_vars),
                   0.04, 1, [1000,500], [0.001,0.01], y_range=y_range)
lr = 1e-4

# %%
m.fit(lr, 3, metrics=[exp_rmspe])
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3), HTML(value='')))
# epoch      trn_loss   val_loss   exp_rmspe
#     0      0.00594    0.318075   0.374806
#     1      0.003692   0.294426   0.361619
#     2      0.00202    0.272119   0.350315
# [array([0.27212]), 0.3503150832329067]

# %%
lrs = np.array([0.0001,0.0005,0.001])

# %%
m.fit(lrs, 5, metrics=[exp_rmspe], cycle_len=3)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=15), HTML(value='')))
# epoch      trn_loss   val_loss   exp_rmspe
#     0      0.001312   0.274526   0.350461
#     1      0.000752   0.275039   0.350521
#     2      0.000587   0.278409   0.351602
#     3      0.00078    0.294704   0.356761
#     4      0.000472   0.29404    0.356506
#     5      0.000393   0.294866   0.357264
#     6      0.000644   0.311447   0.362711
#     7      0.000388   0.299457   0.357883
#     8      0.000331   0.301553   0.359421
#     9      0.00051    0.305087   0.359388
#     10     0.000322   0.303146   0.359116
#     11     0.000254   0.300721   0.358887
#     12     0.000445   0.295195   0.355748
#     13     0.000274   0.302199   0.359015
#     14     0.00023    0.302403   0.359119
# [array([0.3024]), 0.35911930815499277]

# %%
m = md.get_learner(emb_szs, len(df.columns)-len(cat_vars),
                   0.08, 1, [1000,500], [0.0075,0.05], y_range=y_range)
lr = 1e-4

# %%
m.fit(lr, 3, metrics=[exp_rmspe])
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3), HTML(value='')))
# epoch      trn_loss   val_loss   exp_rmspe
#     0      0.008758   0.546052   0.421506
#     1      0.005655   0.463704   0.404556
#  71%|███████   | 1308/1849 [00:10<00:04, 120.57it/s, loss=0.00441]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-8857f3701be9> in <module>()
# ----> 1 m.fit(lr, 3, metrics=[exp_rmspe])
#
# //home/ubuntu/fastai/fastai/learner.py in fit(self, lrs, n_cycle, wds, **kwargs)
#     285         self.sched = None
#     286         layer_opt = self.get_layer_opt(lrs, wds)
# --> 287         return self.fit_gen(self.model, self.data, layer_opt, n_cycle, **kwargs)
#     288
#     289     def warm_up(self, lr, wds=None):
#
# //home/ubuntu/fastai/fastai/learner.py in fit_gen(self, model, data, layer_opt, n_cycle, cycle_len, cycle_mult, cycle_save_name, best_save_name, use_clr, use_clr_beta, metrics, callbacks, use_wd_sched, norm_wds, wds_sched_mult, use_swa, swa_start, swa_eval_freq, **kwargs)
#     232             metrics=metrics, callbacks=callbacks, reg_fn=self.reg_fn, clip=self.clip, fp16=self.fp16,
#     233             swa_model=self.swa_model if use_swa else None, swa_start=swa_start,
# --> 234             swa_eval_freq=swa_eval_freq, **kwargs)
#     235
#     236     def get_layer_groups(self): return self.models.get_layer_groups()
#
# //home/ubuntu/fastai/fastai/model.py in fit(model, data, n_epochs, opt, crit, metrics, callbacks, stepper, swa_model, swa_start, swa_eval_freq, **kwargs)
#     138             batch_num += 1
#     139             for cb in callbacks: cb.on_batch_begin()
# --> 140             loss = model_stepper.step(V(x),V(y), epoch)
#     141             avg_loss = avg_loss * avg_mom + loss * (1-avg_mom)
#     142             debias_loss = avg_loss / (1 - avg_mom**batch_num)
#
# //home/ubuntu/fastai/fastai/model.py in step(self, xs, y, epoch)
#      48     def step(self, xs, y, epoch):
#      49         xtra = []
# ---> 50         output = self.m(*xs)
#      51         if isinstance(output,tuple): output,*xtra = output
#      52         if self.fp16: self.m.zero_grad()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# //home/ubuntu/fastai/fastai/column_data.py in forward(self, x_cat, x_cont)
#     113     def forward(self, x_cat, x_cont):
#     114         if self.n_emb != 0:
# --> 115             x = [e(x_cat[:,i]) for i,e in enumerate(self.embs)]
#     116             x = torch.cat(x, 1)
#     117             x = self.emb_drop(x)
#
# //home/ubuntu/fastai/fastai/column_data.py in <listcomp>(.0)
#     113     def forward(self, x_cat, x_cont):
#     114         if self.n_emb != 0:
# --> 115             x = [e(x_cat[:,i]) for i,e in enumerate(self.embs)]
#     116             x = torch.cat(x, 1)
#     117             x = self.emb_drop(x)
#
# KeyboardInterrupt:

# %%
lrs = np.array([1e-4,1e-3,1e-3])

# %%
m.fit(lrs, 5, metrics=[exp_rmspe], cycle_len=3)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=15), HTML(value='')))
# epoch      trn_loss   val_loss   exp_rmspe
#     0      0.001796   0.355169   0.374618
#     1      0.001092   0.361342   0.377302
#     2      0.000833   0.362966   0.377456
#     3      0.001163   0.355375   0.37446
#     4      0.00074    0.360458   0.375833
#     5      0.000611   0.363161   0.376677
#     6      0.000932   0.353676   0.372152
#     7      0.000588   0.364627   0.37733
#     8      0.000496   0.365939   0.377226
#     9      0.00076    0.361605   0.377755
#     10     0.000509   0.370451   0.378552
#     11     0.000414   0.36921    0.379188
#     12     0.000621   0.373178   0.379671
#     13     0.000445   0.367971   0.376737
#     14     0.000361   0.371632   0.378223
# [array([0.37163]), 0.37822349225454377]

# %%
#Single record 
test_record = df_test.iloc[1500]
test_record
# Out:
# Date           0.000000
# Time          41.000000
# TimeOfDay      7.000000
# Year           0.000000
# Month          5.000000
# Week          18.000000
# Day            1.000000
# Dayofweek      2.000000
# Dayofyear    121.000000
# MaxTemp      143.000000
# MinTemp      184.000000
# Rainfall       1.000000
# DemandMAV      2.146406
# Name: 1644, dtype: float64

# %%
cat = test_record[cat_vars].values.astype(np.int64)[None]
contin = test_record.drop(cat_vars).values.astype(np.float32)[None]

#Prediction
model = m.model
model.eval()
prediction = to_np(model(V(cat), V(contin)))
print(f"Price prediction: {prediction}")
# Out:
# Price prediction: [[3.48364]]

# %%
v = np.exp(prediction)
v
# Out:
# array([[32.57807]], dtype=float32)

# %% [markdown]
# This is at the end of Rossmann, it exports the Test prediction to CSV

# %%
x,y=m.predict_with_targs()

# %%
exp_rmspe(x,y)
# Out:
# 0.4114567076574474

# %%
pred_test=m.predict(True)

# %%
pred_test = np.exp(pred_test)

# %%
data_Test['PriceMAV'] = pred_test

# %%
csv_fn = f'{PATH}test_PriceMAV.csv'

# %%
data_Test[['PriceMAV']].to_csv(csv_fn, index=False)

# %%
FileLink(csv_fn)
# Out:
# //home/ubuntu/fastai/courses/data/EnergyPriceDLModel/test_PriceMAV.csv

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
((val,trn), (y_val,y_trn)) = split_by_idx(val_idx, df.values, yl)

# %%
m = RandomForestRegressor(n_estimators=40, max_features=0.99, min_samples_leaf=2,
                          n_jobs=-1, oob_score=True)
m.fit(trn, y_trn);

# %%
preds = m.predict(val)
m.score(trn, y_trn), m.score(val, y_val), m.oob_score_, exp_rmspe(preds, y_val)
# Out:
# (0.9999797364944755,
#  -0.29659814199356216,
#  0.9998848636608001,
#  0.9016760687152864)
